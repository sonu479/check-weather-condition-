# %% [markdown]
# # working on Real Project with Python
#
# (A part of big data analysis)

# %% [markdown]
# # THE WEATHER DATA SET

# %% [markdown]
# Here, The weather Dataset is a time-series data set with per-hour information about the weather conditions at a particular location. It records temperature, dew point temperature, Relative Humidity,Wind speed,visibility, pressure and conditions.
#
# The data is available as a csv file. We are going to analyze the data set using the pandas data Frame.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Sonu\Desktop\data science project\csv file\weatherHistory.csv")

# %%
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# # How to analyze Dataframe
# # .head()

# %% [markdown]
# # it show the first five rows in the data

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %% [markdown]
# # .Shape()
# # it shows the total no. of rows and column of the dataframe

# %%
data.shape
# Out:
# (96453, 12)

# %% [markdown]
# # .index
# # the attribute provides the index of the dataframe

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %% [markdown]
# # .Columns
# # It shows the name of each column

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'weather'],
#       dtype='object')

# %% [markdown]
# # .dtypes
# # it shows the data -type of each column

# %%
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6226a73926db> in <module>
# ----> 1 data.dtypes
#
# NameError: name 'data' is not defined

# %% [markdown]
# # .unique()
# # In a column, it shows all the unique values, it can be applied on a single column only, not on the whole dataframe.

# %%
data['Visibility (km)'].unique()
# Out:
# array([1.58263e+01, 1.49569e+01, 9.98200e+00, 1.12056e+01, 1.14471e+01,
#        1.12700e+01, 1.10285e+01, 6.19850e+00, 8.05000e+00, 1.03523e+01,
#        6.69760e+00, 9.90150e+00, 5.97310e+00, 1.08031e+01, 1.06743e+01,
#        1.08192e+01, 1.07548e+01, 1.08997e+01, 1.08514e+01, 1.10768e+01,
#        1.08836e+01, 7.61530e+00, 2.65650e+00, 3.81570e+00, 4.49190e+00,
#        4.44360e+00, 5.68330e+00, 3.10730e+00, 3.20390e+00, 1.40553e+01,
#        6.11800e+00, 6.16630e+00, 7.96950e+00, 6.34340e+00, 1.05455e+01,
#        1.49086e+01, 1.50052e+01, 1.58746e+01, 1.00464e+01, 1.00303e+01,
#        1.19784e+01, 1.41680e+01, 5.92480e+00, 1.22360e+00, 7.21280e+00,
#        1.11251e+01, 1.33791e+01, 1.13988e+01, 1.12861e+01, 1.56975e+01,
#        1.48764e+01, 6.84250e+00, 1.53594e+01, 4.29870e+00, 4.12160e+00,
#        4.76560e+00, 2.93020e+00, 5.84430e+00, 9.61170e+00, 9.67610e+00,
#        2.01250e+00, 5.21640e+00, 1.45866e+01, 1.56009e+01, 1.47154e+01,
# ...

# %% [markdown]
# # .nunique()
# # It shows the total no. of unique values in each column. it can be applied on a single column as well as on whole dataframe.

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# weather                       214
# dtype: int64

# %% [markdown]
# # .count
# # It shows the total no. of non-null values in each column.It can be applied on a single column as well as on whole dataframe.

# %%
data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# weather                     96453
# dtype: int64

# %% [markdown]
# # .value_counts
# # In a column, it shows all the unique values with thier count. It can be applied on single column only.

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'weather'],
#       dtype='object')

# %%
data['Precip Type'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        rain
# 1        rain
# 2        rain
# 3        rain
# 4        rain
#          ...
# 96448    rain
# 96449    rain
# 96450    rain
# 96451    rain
# 96452    rain
# Name: Precip Type, Length: 96453, dtype: object>

# %% [markdown]
# # .info()
# # provies basic information about the dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  int64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  weather                   96453 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
#  # Qo.1 Find all the unique 'wind speed' value in the data.

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %% [markdown]
# # Qo.2 Find the number of times when the weather is 'Foggy in the evening.'

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
#value_counts()
data.weather.value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Overcast starting in the afternoon.                                                                        24
# Partly cloudy starting overnight continuing until night and breezy in the afternoon.                       24
# ...

# %%
#filtering
data[data.weather=='Foggy in the evening.']
# Out:
#                       Formatted Date   Summary Precip Type  Temperature (C)  \
# 48     2006-04-11 00:00:00.000 +0200  Overcast        rain        13.772222
# 49     2006-04-11 01:00:00.000 +0200  Overcast        rain        13.283333
# 50     2006-04-11 02:00:00.000 +0200  Overcast        rain         8.633333
# 51     2006-04-11 03:00:00.000 +0200  Overcast        rain        11.250000
# 52     2006-04-11 04:00:00.000 +0200  Overcast        rain        11.183333
# ...                              ...       ...         ...              ...
# 81664  2015-02-04 19:00:00.000 +0100  Overcast        rain         1.111111
# 81665  2015-02-04 20:00:00.000 +0100     Foggy        rain         1.133333
# 81666  2015-02-04 21:00:00.000 +0100  Overcast        rain         1.644444
# 81667  2015-02-04 22:00:00.000 +0100  Overcast        rain         1.566667
# 81668  2015-02-04 23:00:00.000 +0100     Foggy        rain         1.622222
#
# ...

# %%
#groupby()
data.groupby('weather').get_group('Foggy in the evening.')
# Out:
#                       Formatted Date   Summary Precip Type  Temperature (C)  \
# 48     2006-04-11 00:00:00.000 +0200  Overcast        rain        13.772222
# 49     2006-04-11 01:00:00.000 +0200  Overcast        rain        13.283333
# 50     2006-04-11 02:00:00.000 +0200  Overcast        rain         8.633333
# 51     2006-04-11 03:00:00.000 +0200  Overcast        rain        11.250000
# 52     2006-04-11 04:00:00.000 +0200  Overcast        rain        11.183333
# ...                              ...       ...         ...              ...
# 81664  2015-02-04 19:00:00.000 +0100  Overcast        rain         1.111111
# 81665  2015-02-04 20:00:00.000 +0100     Foggy        rain         1.133333
# 81666  2015-02-04 21:00:00.000 +0100  Overcast        rain         1.644444
# 81667  2015-02-04 22:00:00.000 +0100  Overcast        rain         1.566667
# 81668  2015-02-04 23:00:00.000 +0100     Foggy        rain         1.622222
#
# ...

# %% [markdown]
# # Qo.3 Find the number of times when 'wind speed was exactly 14.1197.

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[data['Wind Speed (km/h)']==14.1197]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 618    2006-04-05 18:00:00.000 +0200       Overcast        rain
# 646    2006-04-06 22:00:00.000 +0200       Overcast        rain
# 1264   2006-08-03 16:00:00.000 +0200  Mostly Cloudy        rain
# 1885   2006-12-25 13:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 94761  2016-11-28 13:00:00.000 +0100  Mostly Cloudy        rain
# 94784  2016-11-29 12:00:00.000 +0100  Mostly Cloudy        rain
# 94785  2016-11-29 13:00:00.000 +0100  Mostly Cloudy        rain
# 94833  2016-11-30 13:00:00.000 +0100  Mostly Cloudy        rain
# 96371  2016-09-06 14:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# # Qo. 4 Find out the null values in the data.

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# weather                       0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# weather                     96453
# dtype: int64

# %% [markdown]
# # Qo.5  Rename the column name 'weather' of the dataframe to 'weather condition'.

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.rename(columns={'weather':'weather condition'})
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# # Qo. 6 what is mean 'Humidity'?

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.Humidity.mean()
# Out:
# 0.7348989663358906

# %% [markdown]
# # Qo.7 What is the standard deviation of 'pressure' in this data?

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data['Pressure (millibars)'].std()
# Out:
# 116.96990568258147

# %% [markdown]
# # Qo.8  What is the variance of 'Apparent Temperature ' in this data?

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data['Apparent Temperature (C)'].var()
# Out:
# 114.4225441304794

# %% [markdown]
# # Qo.9 Find all the instance when 'Foggy in the morning.' was recorded?

# %%
#value_counts
data.head(2)
data['weather'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                     20085
# Partly cloudy throughout the day.                                                                      9981
# Partly cloudy until night.                                                                             6169
# Partly cloudy starting in the morning.                                                                 5184
# Foggy in the morning.                                                                                  4201
#                                                                                                       ...
# Breezy starting in the morning continuing until night.                                                   24
# Mostly cloudy throughout the day and breezy starting in the evening continuing until night.              24
# Drizzle starting in the evening.                                                                         24
# ...

# %% [markdown]
# # Qo. 10 find all instance when 'wind speed is above 56 and visibility is less than 45.

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[(data['Wind Speed (km/h)']>56) & (data['Visibility (km)']<45)]
# Out:
#                       Formatted Date                              Summary  \
# 12181  2007-01-29 13:00:00.000 +0100  Dangerously Windy and Partly Cloudy
#
#       Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 12181        rain         8.944444                  3.483333      0.49
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 12181            63.8526                     307          11.4471           0
#
#        Pressure (millibars)                                            weather
# 12181               1009.05  Mostly cloudy throughout the day and windy sta...

# %% [markdown]
# # Qo.11 what is the mean value of each column against 'weather'?

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.groupby('weather').mean()
# Out:
#                                                  Temperature (C)  \
# weather
# Breezy and foggy starting in the evening.               4.523843
# Breezy and foggy until morning.                        -4.869213
# Breezy and mostly cloudy overnight.                     3.755787
# Breezy and partly cloudy in the afternoon.             28.097917
# Breezy in the morning and foggy in the evening.         0.743750
# ...                                                          ...
# Partly cloudy until night.                             17.675495
# Rain throughout the day.                               10.128241
# Rain until afternoon.                                  11.701157
# Rain until morning.                                     9.304630
# Windy in the afternoon.                                 4.538889
#
#                                                  Apparent Temperature (C)  \
# weather
# Breezy and foggy starting in the evening.                        0.485880
# ...

# %% [markdown]
# # Qo. 12 Show all the records where weather condition is 'Foggy in the evening'?

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[data['weather']=='Foggy in the evening.']
# Out:
#                       Formatted Date   Summary Precip Type  Temperature (C)  \
# 48     2006-04-11 00:00:00.000 +0200  Overcast        rain        13.772222
# 49     2006-04-11 01:00:00.000 +0200  Overcast        rain        13.283333
# 50     2006-04-11 02:00:00.000 +0200  Overcast        rain         8.633333
# 51     2006-04-11 03:00:00.000 +0200  Overcast        rain        11.250000
# 52     2006-04-11 04:00:00.000 +0200  Overcast        rain        11.183333
# ...                              ...       ...         ...              ...
# 81664  2015-02-04 19:00:00.000 +0100  Overcast        rain         1.111111
# 81665  2015-02-04 20:00:00.000 +0100     Foggy        rain         1.133333
# 81666  2015-02-04 21:00:00.000 +0100  Overcast        rain         1.644444
# 81667  2015-02-04 22:00:00.000 +0100  Overcast        rain         1.566667
# 81668  2015-02-04 23:00:00.000 +0100     Foggy        rain         1.622222
#
# ...

# %% [markdown]
# # Qo.13 Find all the instances when 'Foggy in the morning'  or 'visibility is above 9.

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
#
#                              weather
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[(data['weather']=='Foggy in the morning.') | (data['Visibility (km)']>9)]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...
